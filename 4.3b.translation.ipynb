# %%
from transformers import pipeline

translator_uk_en = pipeline(
    "translation",
    model="Helsinki-NLP/opus-mt-uk-en"
)

uk_text = "Привіт! Як твої справи?"
translation = translator_uk_en(uk_text)
print(translation)
# Out:
# Device set to use cpu
# [{'translation_text': 'Hi! How are you?'}]

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "dreamlike-art/dreamlike-photoreal-2.0"

# Вибір пристрою
device = "cuda" if torch.cuda.is_available() else "cpu"

# Завантаження моделі (без dtype, він більше не потрібен)
pipe = StableDiffusionPipeline.from_pretrained(model_id)
pipe = pipe.to(device)

# Оптимізації
pipe.enable_attention_slicing()  # економія пам'яті
if device == "cuda":
    try:
        pipe.enable_xformers_memory_efficient_attention()  # швидше на GPU
    except:
        pass

prompt = "photo, a church in the middle of a field of crops, bright cinematic lighting, gopro, fisheye lens"

# Генерація
with torch.inference_mode():
    image = pipe(prompt, height=512, width=512).images[0]

# Збереження
image.save("./result.jpg")
print("Зображення збережено як result.jpg")
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Зображення збережено як result.jpg
